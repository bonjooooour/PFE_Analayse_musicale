# %%
""" 
This scripts permits the convertion of midi files into wav files
To use it first start by "pip install mingus" on your env
"""

import subprocess
from os import walk

# %% [markdown]
# **GUITAR**

# %%
fluidsynth_path = r'midi_utils\fluidsynth-2.3.4-win10-x64\bin\fluidsynth.exe'

guitar_soundfont_file = 'midi_convert\Guitar.SF2' # Sound of a guitar

listeFichiers = []
for (repertoire, sousRepertoires, fichiers) in walk('chords_midi'):
 listeFichiers.extend(fichiers)

for file in listeFichiers:
   midi_file = "chords_midi/" + file
   output_wav = "chords_wav/" + "G_" + file.split('.')[0] + ".wav"
   command = [fluidsynth_path, '-a', 'dsound', '-o', 'audio.driver=dsound', '-i', '-l', '-s', '-g', '1.0', guitar_soundfont_file, midi_file, '-F', output_wav]

   try:
    subprocess.run(command, check=True, shell=True)
    print(f'OK ==> {output_wav}')
   except subprocess.CalledProcessError as e:
    print(f'ERROR : {e}')



fluidsynth_path = r'midi_convert\fluidsynth-2.3.4-win10-x64\bin\fluidsynth.exe'

soundfont_file = 'midi_convert\Guitar.SF2' # Sound of a guitar

listeFichiers = []
for (repertoire, sousRepertoires, fichiers) in walk('chords_midi'):
 listeFichiers.extend(fichiers)

for file in listeFichiers:
   midi_file = "chords_midi/" + file
   output_wav = "chords_wav/" + file.split('.')[0] + ".wav"
   command = [fluidsynth_path, '-a', 'dsound', '-o', 'audio.driver=dsound', '-i', '-l', '-s', '-g', '1.0', soundfont_file, midi_file, '-F', output_wav]

   try:
    subprocess.run(command, check=True, shell=True)
    print(f'OK ==> {output_wav}')
   except subprocess.CalledProcessError as e:
    print(f'ERROR : {e}')
# Out:
# OK ==> chords_wav/G_A#aug.wav
# OK ==> chords_wav/G_A#dim.wav
# OK ==> chords_wav/G_A#maj.wav
# OK ==> chords_wav/G_A#min.wav
# OK ==> chords_wav/G_A#sus2.wav
# OK ==> chords_wav/G_A#sus4.wav
# OK ==> chords_wav/G_Aaug.wav
# OK ==> chords_wav/G_Abaug.wav
# OK ==> chords_wav/G_Abdim.wav
# OK ==> chords_wav/G_Abmaj.wav
# OK ==> chords_wav/G_Abmin.wav
# OK ==> chords_wav/G_Absus2.wav
# OK ==> chords_wav/G_Absus4.wav
# OK ==> chords_wav/G_Adim.wav
# OK ==> chords_wav/G_Amaj.wav
# OK ==> chords_wav/G_Amin.wav
# OK ==> chords_wav/G_Asus2.wav
# OK ==> chords_wav/G_Asus4.wav
# OK ==> chords_wav/G_Baug.wav
# OK ==> chords_wav/G_Bbaug.wav
# OK ==> chords_wav/G_Bbdim.wav
# OK ==> chords_wav/G_Bbmaj.wav
# OK ==> chords_wav/G_Bbmin.wav
# OK ==> chords_wav/G_Bbsus2.wav
# OK ==> chords_wav/G_Bbsus4.wav
# OK ==> chords_wav/G_Bdim.wav
# OK ==> chords_wav/G_Bmaj.wav
# OK ==> chords_wav/G_Bmin.wav
# OK ==> chords_wav/G_Bsus2.wav
# OK ==> chords_wav/G_Bsus4.wav
# OK ==> chords_wav/G_C#aug.wav
# OK ==> chords_wav/G_C#dim.wav
# OK ==> chords_wav/G_C#maj.wav
# OK ==> chords_wav/G_C#min.wav
# OK ==> chords_wav/G_C#sus2.wav
# OK ==> chords_wav/G_C#sus4.wav
# OK ==> chords_wav/G_Caug.wav
# OK ==> chords_wav/G_Cdim.wav
# OK ==> chords_wav/G_Cmaj.wav
# OK ==> chords_wav/G_Cmin.wav
# OK ==> chords_wav/G_Csus2.wav
# OK ==> chords_wav/G_Csus4.wav
# OK ==> chords_wav/G_D#aug.wav
# OK ==> chords_wav/G_D#dim.wav
# OK ==> chords_wav/G_D#maj.wav
# OK ==> chords_wav/G_D#min.wav
# OK ==> chords_wav/G_D#sus2.wav
# OK ==> chords_wav/G_D#sus4.wav
# OK ==> chords_wav/G_Daug.wav
# OK ==> chords_wav/G_Dbaug.wav
# OK ==> chords_wav/G_Dbdim.wav
# OK ==> chords_wav/G_Dbmaj.wav
# OK ==> chords_wav/G_Dbmin.wav
# OK ==> chords_wav/G_Dbsus2.wav
# OK ==> chords_wav/G_Dbsus4.wav
# OK ==> chords_wav/G_Ddim.wav
# OK ==> chords_wav/G_Dmaj.wav
# OK ==> chords_wav/G_Dmin.wav
# OK ==> chords_wav/G_Dsus2.wav
# OK ==> chords_wav/G_Dsus4.wav
# OK ==> chords_wav/G_Eaug.wav
# OK ==> chords_wav/G_Ebaug.wav
# OK ==> chords_wav/G_Ebdim.wav
# OK ==> chords_wav/G_Ebmaj.wav
# OK ==> chords_wav/G_Ebmin.wav
# OK ==> chords_wav/G_Ebsus2.wav
# OK ==> chords_wav/G_Ebsus4.wav
# OK ==> chords_wav/G_Edim.wav
# OK ==> chords_wav/G_Emaj.wav
# OK ==> chords_wav/G_Emin.wav
# OK ==> chords_wav/G_Esus2.wav
# OK ==> chords_wav/G_Esus4.wav
# OK ==> chords_wav/G_F#aug.wav
# OK ==> chords_wav/G_F#dim.wav
# OK ==> chords_wav/G_F#maj.wav
# OK ==> chords_wav/G_F#min.wav
# OK ==> chords_wav/G_F#sus2.wav
# OK ==> chords_wav/G_F#sus4.wav
# OK ==> chords_wav/G_Faug.wav
# OK ==> chords_wav/G_Fdim.wav
# OK ==> chords_wav/G_Fmaj.wav
# OK ==> chords_wav/G_Fmin.wav
# OK ==> chords_wav/G_Fsus2.wav
# OK ==> chords_wav/G_Fsus4.wav
# OK ==> chords_wav/G_G#aug.wav
# OK ==> chords_wav/G_G#dim.wav
# OK ==> chords_wav/G_G#maj.wav
# OK ==> chords_wav/G_G#min.wav
# OK ==> chords_wav/G_G#sus2.wav
# OK ==> chords_wav/G_G#sus4.wav
# OK ==> chords_wav/G_Gaug.wav
# OK ==> chords_wav/G_Gbaug.wav
# OK ==> chords_wav/G_Gbdim.wav
# OK ==> chords_wav/G_Gbmaj.wav
# OK ==> chords_wav/G_Gbmin.wav
# OK ==> chords_wav/G_Gbsus2.wav
# OK ==> chords_wav/G_Gbsus4.wav
# OK ==> chords_wav/G_Gdim.wav
# OK ==> chords_wav/G_Gmaj.wav
# OK ==> chords_wav/G_Gmin.wav
# OK ==> chords_wav/G_Gsus2.wav
# OK ==> chords_wav/G_Gsus4.wav

# %% [markdown]
# **PIANO**

# %%
""" 
This scripts permits the convertion of midi files into wav files
To use it first start by "pip install mingus" on your env
"""

import subprocess
from os import walk

fluidsynth_path = r'midi_utils\fluidsynth-2.3.4-win10-x64\bin\fluidsynth.exe'

piano_soundfont_file = 'midi_convert\Guitar.SF2' # Sound of a guitar

listeFichiers = []
for (repertoire, sousRepertoires, fichiers) in walk('chords_midi'):
 listeFichiers.extend(fichiers)

for file in listeFichiers:
   midi_file = "chords_midi/" + file
   output_wav = "chords_wav/" + "P_" + file.split('.')[0] + ".wav"
   command = [fluidsynth_path, '-a', 'dsound', '-o', 'audio.driver=dsound', '-i', '-l', '-s', '-g', '1.0', piano_soundfont_file, midi_file, '-F', output_wav]

   try:
    subprocess.run(command, check=True, shell=True)
    print(f'OK ==> {output_wav}')
   except subprocess.CalledProcessError as e:
    print(f'ERROR : {e}')
# Out:
# OK ==> chords_wav/P_A#aug.wav
# OK ==> chords_wav/P_A#dim.wav
# OK ==> chords_wav/P_A#maj.wav
# OK ==> chords_wav/P_A#min.wav
# OK ==> chords_wav/P_A#sus2.wav
# OK ==> chords_wav/P_A#sus4.wav
# OK ==> chords_wav/P_Aaug.wav
# OK ==> chords_wav/P_Abaug.wav
# OK ==> chords_wav/P_Abdim.wav
# OK ==> chords_wav/P_Abmaj.wav
# OK ==> chords_wav/P_Abmin.wav
# OK ==> chords_wav/P_Absus2.wav
# OK ==> chords_wav/P_Absus4.wav
# OK ==> chords_wav/P_Adim.wav
# OK ==> chords_wav/P_Amaj.wav
# OK ==> chords_wav/P_Amin.wav
# OK ==> chords_wav/P_Asus2.wav
# OK ==> chords_wav/P_Asus4.wav
# OK ==> chords_wav/P_Baug.wav
# OK ==> chords_wav/P_Bbaug.wav
# OK ==> chords_wav/P_Bbdim.wav
# OK ==> chords_wav/P_Bbmaj.wav
# OK ==> chords_wav/P_Bbmin.wav
# OK ==> chords_wav/P_Bbsus2.wav
# OK ==> chords_wav/P_Bbsus4.wav
# OK ==> chords_wav/P_Bdim.wav
# OK ==> chords_wav/P_Bmaj.wav
# OK ==> chords_wav/P_Bmin.wav
# OK ==> chords_wav/P_Bsus2.wav
# OK ==> chords_wav/P_Bsus4.wav
# OK ==> chords_wav/P_C#aug.wav
# OK ==> chords_wav/P_C#dim.wav
# OK ==> chords_wav/P_C#maj.wav
# OK ==> chords_wav/P_C#min.wav
# OK ==> chords_wav/P_C#sus2.wav
# OK ==> chords_wav/P_C#sus4.wav
# OK ==> chords_wav/P_Caug.wav
# OK ==> chords_wav/P_Cdim.wav
# OK ==> chords_wav/P_Cmaj.wav
# OK ==> chords_wav/P_Cmin.wav
# OK ==> chords_wav/P_Csus2.wav
# OK ==> chords_wav/P_Csus4.wav
# OK ==> chords_wav/P_D#aug.wav
# OK ==> chords_wav/P_D#dim.wav
# OK ==> chords_wav/P_D#maj.wav
# OK ==> chords_wav/P_D#min.wav
# OK ==> chords_wav/P_D#sus2.wav
# OK ==> chords_wav/P_D#sus4.wav
# OK ==> chords_wav/P_Daug.wav
# OK ==> chords_wav/P_Dbaug.wav
# OK ==> chords_wav/P_Dbdim.wav
# OK ==> chords_wav/P_Dbmaj.wav
# OK ==> chords_wav/P_Dbmin.wav
# OK ==> chords_wav/P_Dbsus2.wav
# OK ==> chords_wav/P_Dbsus4.wav
# OK ==> chords_wav/P_Ddim.wav
# OK ==> chords_wav/P_Dmaj.wav
# OK ==> chords_wav/P_Dmin.wav
# OK ==> chords_wav/P_Dsus2.wav
# OK ==> chords_wav/P_Dsus4.wav
# OK ==> chords_wav/P_Eaug.wav
# OK ==> chords_wav/P_Ebaug.wav
# OK ==> chords_wav/P_Ebdim.wav
# OK ==> chords_wav/P_Ebmaj.wav
# OK ==> chords_wav/P_Ebmin.wav
# OK ==> chords_wav/P_Ebsus2.wav
# OK ==> chords_wav/P_Ebsus4.wav
# OK ==> chords_wav/P_Edim.wav
# OK ==> chords_wav/P_Emaj.wav
# OK ==> chords_wav/P_Emin.wav
# OK ==> chords_wav/P_Esus2.wav
# OK ==> chords_wav/P_Esus4.wav
# OK ==> chords_wav/P_F#aug.wav
# OK ==> chords_wav/P_F#dim.wav
# OK ==> chords_wav/P_F#maj.wav
# OK ==> chords_wav/P_F#min.wav
# OK ==> chords_wav/P_F#sus2.wav
# OK ==> chords_wav/P_F#sus4.wav
# OK ==> chords_wav/P_Faug.wav
# OK ==> chords_wav/P_Fdim.wav
# OK ==> chords_wav/P_Fmaj.wav
# OK ==> chords_wav/P_Fmin.wav
# OK ==> chords_wav/P_Fsus2.wav
# OK ==> chords_wav/P_Fsus4.wav
# OK ==> chords_wav/P_G#aug.wav
# OK ==> chords_wav/P_G#dim.wav
# OK ==> chords_wav/P_G#maj.wav
# OK ==> chords_wav/P_G#min.wav
# OK ==> chords_wav/P_G#sus2.wav
# OK ==> chords_wav/P_G#sus4.wav
# OK ==> chords_wav/P_Gaug.wav
# OK ==> chords_wav/P_Gbaug.wav
# OK ==> chords_wav/P_Gbdim.wav
# OK ==> chords_wav/P_Gbmaj.wav
# OK ==> chords_wav/P_Gbmin.wav
# OK ==> chords_wav/P_Gbsus2.wav
# OK ==> chords_wav/P_Gbsus4.wav
# OK ==> chords_wav/P_Gdim.wav
# OK ==> chords_wav/P_Gmaj.wav
# OK ==> chords_wav/P_Gmin.wav
# OK ==> chords_wav/P_Gsus2.wav
# OK ==> chords_wav/P_Gsus4.wav

# %% [markdown]
# **FLUTE**

# %%
""" 
This scripts permits the convertion of midi files into wav files
To use it first start by "pip install mingus" on your env
"""

import subprocess
from os import walk

fluidsynth_path = r'midi_utils\fluidsynth-2.3.4-win10-x64\bin\fluidsynth.exe'

flute_soundfont_file = 'midi_convert\Guitar.SF2' # Sound of a guitar

listeFichiers = []
for (repertoire, sousRepertoires, fichiers) in walk('chords_midi'):
 listeFichiers.extend(fichiers)

for file in listeFichiers:
   midi_file = "chords_midi/" + file
   output_wav = "chords_wav/" + "F_" + file.split('.')[0] + ".wav"
   command = [fluidsynth_path, '-a', 'dsound', '-o', 'audio.driver=dsound', '-i', '-l', '-s', '-g', '1.0', flute_soundfont_file, midi_file, '-F', output_wav]

   try:
    subprocess.run(command, check=True, shell=True)
    print(f'OK ==> {output_wav}')
   except subprocess.CalledProcessError as e:
    print(f'ERROR : {e}')
# Out:
# OK ==> chords_wav/F_A#aug.wav
# OK ==> chords_wav/F_A#dim.wav
# OK ==> chords_wav/F_A#maj.wav
# OK ==> chords_wav/F_A#min.wav
# OK ==> chords_wav/F_A#sus2.wav
# OK ==> chords_wav/F_A#sus4.wav
# OK ==> chords_wav/F_Aaug.wav
# OK ==> chords_wav/F_Abaug.wav
# OK ==> chords_wav/F_Abdim.wav
# OK ==> chords_wav/F_Abmaj.wav
# OK ==> chords_wav/F_Abmin.wav
# OK ==> chords_wav/F_Absus2.wav
# OK ==> chords_wav/F_Absus4.wav
# OK ==> chords_wav/F_Adim.wav
# OK ==> chords_wav/F_Amaj.wav
# OK ==> chords_wav/F_Amin.wav
# OK ==> chords_wav/F_Asus2.wav
# OK ==> chords_wav/F_Asus4.wav
# OK ==> chords_wav/F_Baug.wav
# OK ==> chords_wav/F_Bbaug.wav
# OK ==> chords_wav/F_Bbdim.wav
# OK ==> chords_wav/F_Bbmaj.wav
# OK ==> chords_wav/F_Bbmin.wav
# OK ==> chords_wav/F_Bbsus2.wav
# OK ==> chords_wav/F_Bbsus4.wav
# OK ==> chords_wav/F_Bdim.wav
# OK ==> chords_wav/F_Bmaj.wav
# OK ==> chords_wav/F_Bmin.wav
# OK ==> chords_wav/F_Bsus2.wav
# OK ==> chords_wav/F_Bsus4.wav
# OK ==> chords_wav/F_C#aug.wav
# OK ==> chords_wav/F_C#dim.wav
# OK ==> chords_wav/F_C#maj.wav
# OK ==> chords_wav/F_C#min.wav
# OK ==> chords_wav/F_C#sus2.wav
# OK ==> chords_wav/F_C#sus4.wav
# OK ==> chords_wav/F_Caug.wav
# OK ==> chords_wav/F_Cdim.wav
# OK ==> chords_wav/F_Cmaj.wav
# OK ==> chords_wav/F_Cmin.wav
# OK ==> chords_wav/F_Csus2.wav
# OK ==> chords_wav/F_Csus4.wav
# OK ==> chords_wav/F_D#aug.wav
# OK ==> chords_wav/F_D#dim.wav
# OK ==> chords_wav/F_D#maj.wav
# OK ==> chords_wav/F_D#min.wav
# OK ==> chords_wav/F_D#sus2.wav
# OK ==> chords_wav/F_D#sus4.wav
# OK ==> chords_wav/F_Daug.wav
# OK ==> chords_wav/F_Dbaug.wav
# OK ==> chords_wav/F_Dbdim.wav
# OK ==> chords_wav/F_Dbmaj.wav
# OK ==> chords_wav/F_Dbmin.wav
# OK ==> chords_wav/F_Dbsus2.wav
# OK ==> chords_wav/F_Dbsus4.wav
# OK ==> chords_wav/F_Ddim.wav
# OK ==> chords_wav/F_Dmaj.wav
# OK ==> chords_wav/F_Dmin.wav
# OK ==> chords_wav/F_Dsus2.wav
# OK ==> chords_wav/F_Dsus4.wav
# OK ==> chords_wav/F_Eaug.wav
# OK ==> chords_wav/F_Ebaug.wav
# OK ==> chords_wav/F_Ebdim.wav
# OK ==> chords_wav/F_Ebmaj.wav
# OK ==> chords_wav/F_Ebmin.wav
# OK ==> chords_wav/F_Ebsus2.wav
# OK ==> chords_wav/F_Ebsus4.wav
# OK ==> chords_wav/F_Edim.wav
# OK ==> chords_wav/F_Emaj.wav
# OK ==> chords_wav/F_Emin.wav
# OK ==> chords_wav/F_Esus2.wav
# OK ==> chords_wav/F_Esus4.wav
# OK ==> chords_wav/F_F#aug.wav
# OK ==> chords_wav/F_F#dim.wav
# OK ==> chords_wav/F_F#maj.wav
# OK ==> chords_wav/F_F#min.wav
# OK ==> chords_wav/F_F#sus2.wav
# OK ==> chords_wav/F_F#sus4.wav
# OK ==> chords_wav/F_Faug.wav
# OK ==> chords_wav/F_Fdim.wav
# OK ==> chords_wav/F_Fmaj.wav
# OK ==> chords_wav/F_Fmin.wav
# OK ==> chords_wav/F_Fsus2.wav
# OK ==> chords_wav/F_Fsus4.wav
# OK ==> chords_wav/F_G#aug.wav
# OK ==> chords_wav/F_G#dim.wav
# OK ==> chords_wav/F_G#maj.wav
# OK ==> chords_wav/F_G#min.wav
# OK ==> chords_wav/F_G#sus2.wav
# OK ==> chords_wav/F_G#sus4.wav
# OK ==> chords_wav/F_Gaug.wav
# OK ==> chords_wav/F_Gbaug.wav
# OK ==> chords_wav/F_Gbdim.wav
# OK ==> chords_wav/F_Gbmaj.wav
# OK ==> chords_wav/F_Gbmin.wav
# OK ==> chords_wav/F_Gbsus2.wav
# OK ==> chords_wav/F_Gbsus4.wav
# OK ==> chords_wav/F_Gdim.wav
# OK ==> chords_wav/F_Gmaj.wav
# OK ==> chords_wav/F_Gmin.wav
# OK ==> chords_wav/F_Gsus2.wav
# OK ==> chords_wav/F_Gsus4.wav

# %% [markdown]
# **VIOLIN**

# %%
""" 
This scripts permits the convertion of midi files into wav files
To use it first start by "pip install mingus" on your env
"""

import subprocess
from os import walk

fluidsynth_path = r'midi_utils\fluidsynth-2.3.4-win10-x64\bin\fluidsynth.exe'

violin_soundfont_file = 'midi_convert\198_Legato_strings.SF2' # Sound of a guitar

listeFichiers = []
for (repertoire, sousRepertoires, fichiers) in walk('chords_midi'):
 listeFichiers.extend(fichiers)

for file in listeFichiers:
   midi_file = "chords_midi/" + file
   output_wav = "chords_wav/" + "V_" + file.split('.')[0] + ".wav"
   command = [fluidsynth_path, '-a', 'dsound', '-o', 'audio.driver=dsound', '-i', '-l', '-s', '-g', '1.0', violin_soundfont_file, midi_file, '-F', output_wav]

   try:
    subprocess.run(command, check=True, shell=True)
    print(f'OK ==> {output_wav}')
   except subprocess.CalledProcessError as e:
    print(f'ERROR : {e}')
# Out:
# OK ==> chords_wav/V_A#aug.wav
# OK ==> chords_wav/V_A#dim.wav
# OK ==> chords_wav/V_A#maj.wav
# OK ==> chords_wav/V_A#min.wav
# OK ==> chords_wav/V_A#sus2.wav
# OK ==> chords_wav/V_A#sus4.wav
# OK ==> chords_wav/V_Aaug.wav
# OK ==> chords_wav/V_Abaug.wav
# OK ==> chords_wav/V_Abdim.wav
# OK ==> chords_wav/V_Abmaj.wav
# OK ==> chords_wav/V_Abmin.wav
# OK ==> chords_wav/V_Absus2.wav
# OK ==> chords_wav/V_Absus4.wav
# OK ==> chords_wav/V_Adim.wav
# OK ==> chords_wav/V_Amaj.wav
# OK ==> chords_wav/V_Amin.wav
# OK ==> chords_wav/V_Asus2.wav
# OK ==> chords_wav/V_Asus4.wav
# OK ==> chords_wav/V_Baug.wav
# OK ==> chords_wav/V_Bbaug.wav
# OK ==> chords_wav/V_Bbdim.wav
# OK ==> chords_wav/V_Bbmaj.wav
# OK ==> chords_wav/V_Bbmin.wav
# OK ==> chords_wav/V_Bbsus2.wav
# OK ==> chords_wav/V_Bbsus4.wav
# OK ==> chords_wav/V_Bdim.wav
# OK ==> chords_wav/V_Bmaj.wav
# OK ==> chords_wav/V_Bmin.wav
# OK ==> chords_wav/V_Bsus2.wav
# OK ==> chords_wav/V_Bsus4.wav
# OK ==> chords_wav/V_C#aug.wav
# OK ==> chords_wav/V_C#dim.wav
# OK ==> chords_wav/V_C#maj.wav
# OK ==> chords_wav/V_C#min.wav
# OK ==> chords_wav/V_C#sus2.wav
# OK ==> chords_wav/V_C#sus4.wav
# OK ==> chords_wav/V_Caug.wav
# OK ==> chords_wav/V_Cdim.wav
# OK ==> chords_wav/V_Cmaj.wav
# OK ==> chords_wav/V_Cmin.wav
# OK ==> chords_wav/V_Csus2.wav
# OK ==> chords_wav/V_Csus4.wav
# OK ==> chords_wav/V_D#aug.wav
# OK ==> chords_wav/V_D#dim.wav
# OK ==> chords_wav/V_D#maj.wav
# OK ==> chords_wav/V_D#min.wav
# OK ==> chords_wav/V_D#sus2.wav
# OK ==> chords_wav/V_D#sus4.wav
# OK ==> chords_wav/V_Daug.wav
# OK ==> chords_wav/V_Dbaug.wav
# OK ==> chords_wav/V_Dbdim.wav
# OK ==> chords_wav/V_Dbmaj.wav
# OK ==> chords_wav/V_Dbmin.wav
# OK ==> chords_wav/V_Dbsus2.wav
# OK ==> chords_wav/V_Dbsus4.wav
# OK ==> chords_wav/V_Ddim.wav
# OK ==> chords_wav/V_Dmaj.wav
# OK ==> chords_wav/V_Dmin.wav
# OK ==> chords_wav/V_Dsus2.wav
# OK ==> chords_wav/V_Dsus4.wav
# OK ==> chords_wav/V_Eaug.wav
# OK ==> chords_wav/V_Ebaug.wav
# OK ==> chords_wav/V_Ebdim.wav
# OK ==> chords_wav/V_Ebmaj.wav
# OK ==> chords_wav/V_Ebmin.wav
# OK ==> chords_wav/V_Ebsus2.wav
# OK ==> chords_wav/V_Ebsus4.wav
# OK ==> chords_wav/V_Edim.wav
# OK ==> chords_wav/V_Emaj.wav
# OK ==> chords_wav/V_Emin.wav
# OK ==> chords_wav/V_Esus2.wav
# OK ==> chords_wav/V_Esus4.wav
# OK ==> chords_wav/V_F#aug.wav
# OK ==> chords_wav/V_F#dim.wav
# OK ==> chords_wav/V_F#maj.wav
# OK ==> chords_wav/V_F#min.wav
# OK ==> chords_wav/V_F#sus2.wav
# OK ==> chords_wav/V_F#sus4.wav
# OK ==> chords_wav/V_Faug.wav
# OK ==> chords_wav/V_Fdim.wav
# OK ==> chords_wav/V_Fmaj.wav
# OK ==> chords_wav/V_Fmin.wav
# OK ==> chords_wav/V_Fsus2.wav
# OK ==> chords_wav/V_Fsus4.wav
# OK ==> chords_wav/V_G#aug.wav
# OK ==> chords_wav/V_G#dim.wav
# OK ==> chords_wav/V_G#maj.wav
# OK ==> chords_wav/V_G#min.wav
# OK ==> chords_wav/V_G#sus2.wav
# OK ==> chords_wav/V_G#sus4.wav
# OK ==> chords_wav/V_Gaug.wav
# OK ==> chords_wav/V_Gbaug.wav
# OK ==> chords_wav/V_Gbdim.wav
# OK ==> chords_wav/V_Gbmaj.wav
# OK ==> chords_wav/V_Gbmin.wav
# OK ==> chords_wav/V_Gbsus2.wav
# OK ==> chords_wav/V_Gbsus4.wav
# OK ==> chords_wav/V_Gdim.wav
# OK ==> chords_wav/V_Gmaj.wav
# OK ==> chords_wav/V_Gmin.wav
# OK ==> chords_wav/V_Gsus2.wav
# OK ==> chords_wav/V_Gsus4.wav
